# %%
#%% import libraries from local directory
import os
import sys
import numpy as np
import xarray as xr
import pandas as pd
import geopandas as gpd
from os.path import relpath
from pybufrkit.decoder import Decoder
from geopandas.tools import sjoin
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.ops import nearest_points 
import requests
from datetime import datetime, timedelta
from pathlib import Path
from dateutil import rrule
import re
import xml.etree.ElementTree as ET
decoder = Decoder()
#wor_dir="/home/fbf/"
wor_dir="C:\\Users\\ATeklesadik\\OneDrive - Rode Kruis\\Documents\\documents\\Typhoon-Impact-based-forecasting-model"
# Out:
# c:\ProgramData\miniforge3\envs\climada_env\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### Hindcast analysis

# %%
import os
 
import re

import pandas as pd
import xml.etree.ElementTree as ET

 
import requests
from datetime import datetime, timedelta
from pathlib import Path

from dateutil import rrule





#wor_dir='c:/Users/ATeklesadik/OneDrive - Rode Kruis/Documents/documents/Typhoon-Impact-based-forecasting-model/'
wor_dir="C:\\Users\\ATeklesadik\\OneDrive - Rode Kruis\\Documents\\documents\\Typhoon-Impact-based-forecasting-model"
typhoon_metadata_filename = os.path.join(wor_dir, "IBF-Typhoon-model\\data\\metadata_typhoons_full.csv")
typhoon_metadata = pd.read_csv(typhoon_metadata_filename, delimiter=",")

list_of_events=[
    'krosa2013','fengshen2008','haiyan2013','rammasun2014', 'hagupit2014',  'haima2016','phanfone2019', 
    'nock-ten2016' 
    ]
typhoon_metadata['landfall_dd_hh']=typhoon_metadata.apply(lambda x:x.landfalldate +' '+ x.landfall_time,axis=1	)
typhoon_metadata['landfall_']=typhoon_metadata.apply(lambda x:datetime.strptime(x.landfall_dd_hh, '%d/%m/%Y %H:%M:00'),axis=1	)
 
 
typhoon_metadata=typhoon_metadata.query('typhoon in @list_of_events')
typhoon_metadata['landfall_dd_hh']=typhoon_metadata.apply(lambda x:x.landfalldate +' '+ x.landfall_time,axis=1	)
typhoon_metadata['landfall_']=typhoon_metadata.apply(lambda x:datetime.strptime(x.landfall_dd_hh, '%d/%m/%Y %H:%M:00'),axis=1	)
typhoon_metadata=typhoon_metadata.query('typhoon in @list_of_events')





 
typhoon_metadata["international"] = typhoon_metadata['typhoon'].apply(lambda x:x[:-4])
typhoon_metadata["year"] = typhoon_metadata['landfall_'].apply(lambda x:x.year)

 
 
df_typhoons = typhoon_metadata

# %% [markdown]
# ### download and process input data

# %%
def hour_rounder(t):
    # Rounds to nearest hour by adding a timedelta hour if minute >= 30
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour) - timedelta(hours=t.hour-6))

#from constants import save_dir


tem_dir="C:\\Users\\ATeklesadik\\OneDrive - Rode Kruis\\Documents\\documents\\Typhoon-Impact-based-forecasting-model\\IBF-Typhoon-model\\data\\wind_data\\"
save_dir=os.path.join(tem_dir,'temp')
save_dir = Path(save_dir)

email = input('email: ')
pswd = input('password: ')

values = {'email' : email, 'passwd' : pswd, 'action' : 'login'}
login_url = 'https://rda.ucar.edu/cgi-bin/login'

ret = requests.post(login_url, data=values)


values = {'email' : email, 'passwd' : pswd, 'action' : 'login'}
login_url = 'https://rda.ucar.edu/cgi-bin/login'

ret = requests.post(login_url, data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)

dspath = 'https://rda.ucar.edu/data/ds330.3/'

verbose = True


for date,row in typhoon_metadata.iterrows():
    start_date =row['landfall_'] - timedelta(hours=72)
    start_date =hour_rounder(start_date)
    end_date = row['landfall_'] 
    
    date_list = rrule.rrule(rrule.HOURLY, 
                            dtstart=start_date, 
                            until=end_date,
                            interval=6)
    
    for date in date_list:
        ymd = date.strftime("%Y%m%d")
        ymdhms = date.strftime("%Y%m%d%H%M%S")
        server = "test" if date < datetime(2008, 8, 1) else "prod"
        file = f'ecmf/{date.year}/{ymd}/z_tigge_c_ecmf_{ymdhms}_ifs_glob_{server}_all_glo.xml'
        filename = dspath + file
        outfile = save_dir / "xml" / os.path.basename(filename)
        # Don't download if exists already
        if outfile.exists():
            if verbose:
                print(f'{file} already exists')
            continue
        req = requests.get(filename, cookies = ret.cookies, allow_redirects=True)
        if req.status_code != 200:
            if verbose:
                print(f'{file} invalid URL')
            continue
        if verbose:
            print(f'{file} downloading')
        open(outfile, 'wb').write(req.content)
  

def xml2csv(filename):
    print(f"{filename}")
    try:
        tree = ET.parse(filename)
    except ET.ParseError:
        print("Error with file, skipping")
        return
    root = tree.getroot()

    prod_center=root.find('header/productionCenter').text
    baseTime=root.find('header/baseTime').text

    ## Create one dictonary for each time point, and append it to a list
    for members in root.findall('data'):
        mtype=members.get('type')
        if mtype not in ['forecast', 'ensembleForecast']:
            continue
        for members2 in members.findall('disturbance'):
            cyclone_name = [name.text.lower().strip() for name in members2.findall('cycloneName')]
            if not cyclone_name:
                continue
            cyclone_name = cyclone_name[0].lower()
            if cyclone_name not in list(df_typhoons["international"]):
                continue
            print(f"Found typhoon {cyclone_name}")
            for members3 in members2.findall('fix'):
                tem_dic = {}
                tem_dic['mtype']=[mtype]
                tem_dic['product']=[re.sub('\s+',' ',prod_center).strip().lower()]
                tem_dic['cyc_number'] = [name.text for name in members2.findall('cycloneNumber')]
                tem_dic['ensemble']=[members.get('member')]
                tem_dic['speed'] = [name.text for name in members3.findall('cycloneData/maximumWind/speed')]
                tem_dic['pressure'] = [name.text for name in members3.findall('cycloneData/minimumPressure/pressure')]
                time = [name.text for name in members3.findall('validTime')]
                tem_dic['time'] = ['/'.join(time[0].split('T')[0].split('-'))+', '+time[0].split('T')[1][:-1]]
                tem_dic['lat'] = [name.text for name in members3.findall('latitude')]
                tem_dic['lon']= [name.text for name in members3.findall('longitude')]
                tem_dic['lead_time']=[members3.get('hour')]
                tem_dic['forecast_time'] = ['/'.join(baseTime.split('T')[0].split('-'))+', '+baseTime.split('T')[1][:-1]]
                tem_dic1 = dict( [(k,''.join(str(e).lower().strip() for e in v)) for k,v in tem_dic.items()])
                # Save to CSV
                outfile = save_dir / f"csv/{cyclone_name}_all.csv"
                pd.DataFrame(tem_dic1, index=[0]).to_csv(outfile, mode='a', header=not os.path.exists(outfile), index=False)


 

# Get list of filenames
filename_list = sorted(list(Path(save_dir / "xml").glob('*.xml')))

for filename in filename_list:
    xml2csv(filename)

# %% [markdown]
# ### calculate wind field data for each manucipality

# %%
typhoon_forecast_dict={}

list_of_events=['nock-ten2016']
filename_list1=[fname for fname in filename_list if os.path.basename(fname) in ['nock-ten_2016.csv']]

import time
for i,row, in typhoon_metadata.iterrows():
    landfall_=row['landfall_']
    landfall_time=datetime.strptime(landfall_.strftime('%Y/%m/%d, %H:%M:%S'), '%Y/%m/%d,  %H:%M:%S') 
    typhoon_name=row['typhoon']
    if typhoon_name in list_of_events:#'hagupit2014':  
        tr_data=[tr for tr in DATA_YPHOON1 if (tr.name+tr.sid[:4])==typhoon_name]
        forecast_time_list=sorted(list(set([tr.forecast_time  for tr in tr_data])), reverse=False)
        for forecast_time in forecast_time_list:
            lead_time1=(landfall_time-forecast_time).total_seconds() / 3600 
            if lead_time1 > 23:                
                tr_data2=[tr for tr in tr_data if tr.forecast_time==forecast_time]
                tracks = TCTracks()
                # Select typhoons that are in the typhoon event sheet
                tracks.data =tr_data2 # [ tr for tr in DATA_YPHOON if (tr.name + tr.sid[:4]) in typhoon_events]
                #tracks.data = [adjust_tracks(tr) for tr in Typhoons.data]
                tracks.equal_timestep(0.5)
                
                TYphoon = TropCyclone()
                TYphoon.set_from_tracks(tracks, cent, store_windfields=True,metric="geosphere")
                windfield=TYphoon.windfields
                #calculate wind field for each ensamble members 
                df = pd.DataFrame(data=cent.coord)
                df["centroid_id"] = "id" + (df.index).astype(str)
                centroid_idx = df["centroid_id"].values
                ncents = cent.size
                df = df.rename(columns={0: "lat", 1: "lon"})
                threshold = 0.1

                df_ = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat))
                df_.crs = {"init": "epsg:4326"}
                df_ = df_.to_crs("EPSG:4326")
                df_admin = sjoin(df_, admin, how="left")
                # To remove points that are in water
                df_admin = df_admin.dropna()

                list_intensity = []
                distan_track = []

                list_intensity=[]
                distan_track=[]
                
                for i in range(len(tracks.data)):        
                    nsteps = windfield[i].shape[0]
                    tr=tracks.data[i]
                    centroid_id = np.tile(centroid_idx, nsteps)
                    intensity_3d = windfield[i].toarray().reshape(nsteps, ncents, 2)
                    intensity = np.linalg.norm(intensity_3d, axis=-1).ravel()
                    timesteps = np.repeat(tracks.data[i].time.values, ncents)
                    timesteps = timesteps.reshape((nsteps, ncents)).ravel()
                    inten_tr = pd.DataFrame({
                            'centroid_id': centroid_id,
                            'value': intensity,
                            'timestamp': timesteps,})
                    
                    inten_tr = inten_tr[inten_tr.value > threshold]
                    
                    inten_tr['storm_id'] = tr.sid
                    #inten_tr['ens_id'] =tr.sid+'_'+str(tr.ensemble_number)
                    inten_tr['name'] = tr.name
                    
                    inten_tr = (pd.merge(inten_tr, df_admin, how='outer', on='centroid_id')
                                .dropna()
                                .groupby(['adm3_pcode'], as_index=False)
                                .agg({"value": ['count', 'max']}))
                    
                    
                    inten_tr.columns = [x for x in ['adm3_pcode', 'value_count', 'v_max']]
                    inten_tr['storm_id'] = tr.sid
                    inten_tr['name'] = tr.name
                    inten_tr['forecast_time']=tr.forecast_time
                    inten_tr['lead_time']=lead_time1
                    list_intensity.append(inten_tr)
 
                
        
                    distan_track1=[]
                    
                    for index, row in df.iterrows():
                        dist=np.min(np.sqrt(np.square(tr.lat.values-row['lat'])+np.square(tr.lon.values-row['lon'])))
                        distan_track1.append(dist*111)
                    dist_tr = pd.DataFrame({'centroid_id': centroid_idx,'value': distan_track1})

                    dist_tr = (pd.merge(dist_tr, df_admin, how='outer', on='centroid_id')
                                .dropna()
                                .groupby(['adm3_pcode'], as_index=False)
                                .agg({'value': 'min'}))
                    

                    
                    dist_tr.columns = [x for x in ['adm3_pcode', 'dis_track_min']]  # join_left_df_.columns.ravel()]
                    dist_tr['storm_id'] = tr.sid
                    #dist_tr['name'] = tr.name
                    distan_track.append(dist_tr)
    
                df_intensity_ = pd.concat(list_intensity)
                distan_track1 = pd.concat(distan_track)

                typhhon_df =  pd.merge(df_intensity_, distan_track1,  how='left', on=['adm3_pcode','storm_id']) 

                # Check if there are duplicates for municipality and storm_id


                #distan_track1 = pd.concat(distan_track)

                #typhhon_df = df_intensity_ #pd.merge(df_intensity_, distan_track1,  how='left', on=['adm3_pcode','storm_id']) 

                # Check if there are duplicates for municipality and storm_id

                duplicate = typhhon_df[
                    typhhon_df.duplicated(subset=["adm3_pcode", "storm_id"], keep=False)
                ]



                    
                file_name = (f"IBF-typhoon-model\\data\\wind_data\\hindcast\\hindcast_{typhoon_name}_{lead_time1}.csv")

                path = os.path.join(wor_dir, file_name)

                typhhon_df.to_csv(path)

# %% [markdown]
# ### Modeling

# %%
# standard libraries
import datetime as dt
from pathlib import Path

import pandas as pd
import numpy as np
import os
# additional libraries
import cartopy.crs as ccrs
import cftime
import geopandas as gpd
import matplotlib.cm as cm_mp
from matplotlib.collections import LineCollection
from matplotlib.colors import BoundaryNorm, ListedColormap
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np

import scipy.io.matlab as matlab
from shapely.geometry import Point, LineString, MultiLineString
#from sklearn.neighbors import DistanceMetric
import statsmodels.api as sm
import xarray as xr

import random
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from xgboost import XGBClassifier

from sklearn.feature_selection import RFECV
import pandas as pd
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    StratifiedKFold,
    train_test_split,
    KFold)
 
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import (
    mean_absolute_error, 
    mean_squared_error,
    recall_score,
    f1_score,
    precision_score,
    confusion_matrix,
    make_scorer)

import xgboost as xgb
import glob

from geopandas.tools import sjoin
 
from shapely.ops import nearest_points
import datetime as datetime

wor_dir="C:\\Users\\ATeklesadik\\OneDrive - Rode Kruis\\Documents\\documents\\Typhoon-Impact-based-forecasting-model"
f_path = os.path.join(wor_dir,"IBF-typhoon-model/data/all_predisaster_indicators.csv") 
df_predisasters = pd.read_csv(f_path)


def division(x, y):
    try:
        value =100* (x / y)
        
    except:
        value = np.nan
    
    return 100 if value>100 else value


# Setting the new damage threshold

df_predisasters["vulnerable_groups"] = df_predisasters.apply(lambda x: division(x["vulnerable_groups"], x["Total Pop"]), axis=1).values
#df_total["pantawid_pamilya_beneficiary"] = df_total.apply(lambda x: division(x["Total # of Active HHs"], x["Housing Units"]), axis=1).values
df_predisasters["pantawid_pamilya_beneficiary"] = df_predisasters.apply(lambda x: division(x["pantawid_total_pop"], x["Total Pop"]), axis=1).values
#%%
#############################



 
combined_input_data=pd.read_csv(os.path.join(wor_dir,"IBF-typhoon-model/data/model_input/df_modelinput_sep.csv")) 
tphoon_events=combined_input_data[['typhoon','DAM_perc_dmg']].groupby('typhoon').size().to_dict()
### for hyper parameter optimization we looped over typhoon events with at least 100 data entries  

 
def set_zeros(x):
    x_max = 25
    y_max = 50    
    v_max = x[0]
    rainfall_max = x[1]
    damage = x[2]
    if pd.notnull(damage):
        value = damage
    elif v_max > x_max or rainfall_max > y_max:
        value =damage
    elif (v_max < np.sqrt((1- (rainfall_max**2/y_max ** 2))*x_max ** 2)):
        value = 0
    #elif ((v_max < x_max)  and  (rainfall_max_6h < y_max) ):
    #elif (v_max < x_max ):
    #value = 0
    else:
        value = np.nan
    return value

combined_input_data["DAM_perc_dmg"] = combined_input_data[["HAZ_v_max", "HAZ_rainfall_Total", "DAM_perc_dmg"]].apply(set_zeros, axis="columns")


selected_features_xgb_regr= [#'HAZ_rainfall_max_24h',
                                       'HAZ_v_max',
                                       'HAZ_dis_track_min',
                                       'TOP_mean_slope',
                                       'TOP_mean_elevation_m',
                                       'TOP_ruggedness_stdev',
                                       'TOP_mean_ruggedness',
                                       'TOP_slope_stdev',
                                       'VUL_poverty_perc',
                                       'GEN_with_coast',
                                       'VUL_Housing_Units',
                                       'VUL_StrongRoof_StrongWall',
                                       'VUL_StrongRoof_LightWall',
                                       'VUL_StrongRoof_SalvageWall',
                                       'VUL_LightRoof_StrongWall',
                                       'VUL_LightRoof_LightWall',
                                       'VUL_SalvagedRoof_StrongWall',
                                       'VUL_SalvagedRoof_LightWall',
                                       'VUL_SalvagedRoof_SalvageWall',
                                       'VUL_vulnerable_groups',
                                       'VUL_pantawid_pamilya_beneficiary']



# split data into train and test sets

SEED2 = 314159265
SEED = 31 
 
test_size = 0.1

# Full dataset for feature selection

combined_input_data_ = combined_input_data[combined_input_data['DAM_perc_dmg'].notnull()]


X = combined_input_data_[selected_features_xgb_regr]
y = combined_input_data_["DAM_perc_dmg"]
 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=SEED)





#from sklearn.metrics import mean_absolute_error

 
reg = xgb.XGBRegressor(base_score=0.5,
             booster='gbtree', 
             subsample=0.8,
             eta=0.05,
             max_depth=8, 
             colsample_bylevel=1,
             colsample_bynode=1, 
             colsample_bytree=1,
             early_stopping_rounds=10, 
             eval_metric=mean_absolute_error,
             gamma=1, 
             objective='reg:squarederror',
             gpu_id=-1, 
             grow_policy='depthwise', 
             learning_rate=0.025,
             min_child_weight=1,
             n_estimators=200,        
             random_state=42,
             tree_method="hist",
             )

eval_set=[(X_train, y_train), ( X_test, y_test)]

reg.fit(X, y, eval_set=eval_set)

#%%%

 
 


#%%%%%%%%

#Adding the wind data only for events with impact data
# Out:
# C:\Users\ATeklesadik\AppData\Local\Temp\ipykernel_41140\365971716.py:92: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   v_max = x[0]
# C:\Users\ATeklesadik\AppData\Local\Temp\ipykernel_41140\365971716.py:93: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rainfall_max = x[1]
# C:\Users\ATeklesadik\AppData\Local\Temp\ipykernel_41140\365971716.py:94: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   damage = x[2]
# [0]	validation_0-rmse:9.67578	validation_0-mean_absolute_error:2.72172	validation_1-rmse:7.43475	validation_1-mean_absolute_error:2.23981
# [1]	validation_0-rmse:9.51894	validation_0-mean_absolute_error:2.67548	validation_1-rmse:7.30887	validation_1-mean_absolute_error:2.20093
# [2]	validation_0-rmse:9.36177	validation_0-mean_absolute_error:2.63117	validation_1-rmse:7.16964	validation_1-mean_absolute_error:2.16175
# [3]	validation_0-rmse:9.20878	validation_0-mean_absolute_error:2.58787	validation_1-rmse:7.03492	validation_1-mean_absolute_error:2.12347
# [4]	validation_0-rmse:9.05999	validation_0-mean_absolute_error:2.54537	validation_1-rmse:6.89342	validation_1-mean_absolute_error:2.08641
# [5]	validation_0-rmse:8.91768	validation_0-mean_absolute_error:2.50289	validation_1-rmse:6.77606	validation_1-mean_absolute_error:2.04976
# [6]	validation_0-rmse:8.77390	validation_0-mean_absolute_error:2.46445	validation_1-rmse:6.66202	validation_1-mean_absolute_error:2.02083
# [7]	validation_0-rmse:8.63681	validation_0-mean_absolute_error:2.42641	validation_1-rmse:6.55213	validation_1-mean_absolute_error:1.98826
# [8]	validation_0-rmse:8.49151	validation_0-mean_absolute_error:2.38767	validation_1-rmse:6.44560	validation_1-mean_absolute_error:1.95837
# [9]	validation_0-rmse:8.35906	validation_0-mean_absolute_error:2.35153	validation_1-rmse:6.32556	validation_1-mean_absolute_error:1.92691
# [10]	validation_0-rmse:8.23064	validation_0-mean_absolute_error:2.31596	validation_1-rmse:6.23339	validation_1-mean_absolute_error:1.90175
# [11]	validation_0-rmse:8.10335	validation_0-mean_absolute_error:2.28179	validation_1-rmse:6.12445	validation_1-mean_absolute_error:1.87188
# [12]	validation_0-rmse:7.97766	validation_0-mean_absolute_error:2.24852	validation_1-rmse:6.03063	validation_1-mean_absolute_error:1.84694
# [13]	validation_0-rmse:7.86092	validation_0-mean_absolute_error:2.21680	validation_1-rmse:5.93568	validation_1-mean_absolute_error:1.82265
# [14]	validation_0-rmse:7.74255	validation_0-mean_absolute_error:2.18617	validation_1-rmse:5.82979	validation_1-mean_absolute_error:1.79559
# [15]	validation_0-rmse:7.62265	validation_0-mean_absolute_error:2.15570	validation_1-rmse:5.74058	validation_1-mean_absolute_error:1.77328
# [16]	validation_0-rmse:7.51172	validation_0-mean_absolute_error:2.12765	validation_1-rmse:5.64836	validation_1-mean_absolute_error:1.75097
# [17]	validation_0-rmse:7.40334	validation_0-mean_absolute_error:2.09832	validation_1-rmse:5.55792	validation_1-mean_absolute_error:1.72909
# [18]	validation_0-rmse:7.29213	validation_0-mean_absolute_error:2.07035	validation_1-rmse:5.46046	validation_1-mean_absolute_error:1.70354
# [19]	validation_0-rmse:7.18568	validation_0-mean_absolute_error:2.04391	validation_1-rmse:5.38247	validation_1-mean_absolute_error:1.68377
# [20]	validation_0-rmse:7.08358	validation_0-mean_absolute_error:2.01761	validation_1-rmse:5.29605	validation_1-mean_absolute_error:1.66172
# [21]	validation_0-rmse:6.97803	validation_0-mean_absolute_error:1.99086	validation_1-rmse:5.21334	validation_1-mean_absolute_error:1.64225
# C:\Users\ATeklesadik\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:160: UserWarning: [10:26:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0cec3277c4d9d0165-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:45: `gpu_id` is deprecated since2.0.0, use `device` instead. E.g. device=cpu/cuda/cuda:0
#   warnings.warn(smsg, UserWarning)
# [22]	validation_0-rmse:6.88472	validation_0-mean_absolute_error:1.96635	validation_1-rmse:5.12346	validation_1-mean_absolute_error:1.62157
# [23]	validation_0-rmse:6.78876	validation_0-mean_absolute_error:1.94299	validation_1-rmse:5.04938	validation_1-mean_absolute_error:1.60259
# [24]	validation_0-rmse:6.69240	validation_0-mean_absolute_error:1.91976	validation_1-rmse:4.98098	validation_1-mean_absolute_error:1.58584
# [25]	validation_0-rmse:6.59713	validation_0-mean_absolute_error:1.89622	validation_1-rmse:4.92176	validation_1-mean_absolute_error:1.57008
# [26]	validation_0-rmse:6.50576	validation_0-mean_absolute_error:1.87384	validation_1-rmse:4.85385	validation_1-mean_absolute_error:1.55286
# [27]	validation_0-rmse:6.41675	validation_0-mean_absolute_error:1.85222	validation_1-rmse:4.78367	validation_1-mean_absolute_error:1.53417
# [28]	validation_0-rmse:6.33386	validation_0-mean_absolute_error:1.83130	validation_1-rmse:4.70966	validation_1-mean_absolute_error:1.51491
# [29]	validation_0-rmse:6.24692	validation_0-mean_absolute_error:1.81000	validation_1-rmse:4.64996	validation_1-mean_absolute_error:1.49943
# [30]	validation_0-rmse:6.16911	validation_0-mean_absolute_error:1.79197	validation_1-rmse:4.59505	validation_1-mean_absolute_error:1.48552
# [31]	validation_0-rmse:6.08567	validation_0-mean_absolute_error:1.77232	validation_1-rmse:4.53835	validation_1-mean_absolute_error:1.46881
# [32]	validation_0-rmse:6.00930	validation_0-mean_absolute_error:1.75417	validation_1-rmse:4.47793	validation_1-mean_absolute_error:1.45521
# [33]	validation_0-rmse:5.93537	validation_0-mean_absolute_error:1.73616	validation_1-rmse:4.43345	validation_1-mean_absolute_error:1.44111
# [34]	validation_0-rmse:5.86215	validation_0-mean_absolute_error:1.71788	validation_1-rmse:4.38176	validation_1-mean_absolute_error:1.42590
# [35]	validation_0-rmse:5.78624	validation_0-mean_absolute_error:1.70066	validation_1-rmse:4.33713	validation_1-mean_absolute_error:1.41335
# [36]	validation_0-rmse:5.71451	validation_0-mean_absolute_error:1.68349	validation_1-rmse:4.28597	validation_1-mean_absolute_error:1.40019
# [37]	validation_0-rmse:5.64304	validation_0-mean_absolute_error:1.66668	validation_1-rmse:4.23767	validation_1-mean_absolute_error:1.38626
# [38]	validation_0-rmse:5.57465	validation_0-mean_absolute_error:1.65006	validation_1-rmse:4.18981	validation_1-mean_absolute_error:1.37185
# [39]	validation_0-rmse:5.50967	validation_0-mean_absolute_error:1.63460	validation_1-rmse:4.13937	validation_1-mean_absolute_error:1.35751
# [40]	validation_0-rmse:5.44258	validation_0-mean_absolute_error:1.61883	validation_1-rmse:4.10255	validation_1-mean_absolute_error:1.34826
# [41]	validation_0-rmse:5.37718	validation_0-mean_absolute_error:1.60416	validation_1-rmse:4.04914	validation_1-mean_absolute_error:1.33534
# [42]	validation_0-rmse:5.31026	validation_0-mean_absolute_error:1.58927	validation_1-rmse:4.01156	validation_1-mean_absolute_error:1.32462
# [43]	validation_0-rmse:5.24963	validation_0-mean_absolute_error:1.57515	validation_1-rmse:3.97340	validation_1-mean_absolute_error:1.31271
# [44]	validation_0-rmse:5.18863	validation_0-mean_absolute_error:1.56071	validation_1-rmse:3.93565	validation_1-mean_absolute_error:1.30186
# [45]	validation_0-rmse:5.12556	validation_0-mean_absolute_error:1.54686	validation_1-rmse:3.88818	validation_1-mean_absolute_error:1.28962
# [46]	validation_0-rmse:5.06548	validation_0-mean_absolute_error:1.53361	validation_1-rmse:3.84303	validation_1-mean_absolute_error:1.27750
# [47]	validation_0-rmse:5.00791	validation_0-mean_absolute_error:1.52029	validation_1-rmse:3.79458	validation_1-mean_absolute_error:1.26353
# [48]	validation_0-rmse:4.94902	validation_0-mean_absolute_error:1.50665	validation_1-rmse:3.75993	validation_1-mean_absolute_error:1.25407
# [49]	validation_0-rmse:4.89355	validation_0-mean_absolute_error:1.49364	validation_1-rmse:3.72934	validation_1-mean_absolute_error:1.24632
# [50]	validation_0-rmse:4.84174	validation_0-mean_absolute_error:1.48172	validation_1-rmse:3.69767	validation_1-mean_absolute_error:1.23803
# [51]	validation_0-rmse:4.79371	validation_0-mean_absolute_error:1.46995	validation_1-rmse:3.67173	validation_1-mean_absolute_error:1.22825
# [52]	validation_0-rmse:4.74226	validation_0-mean_absolute_error:1.45810	validation_1-rmse:3.63923	validation_1-mean_absolute_error:1.21711
# [53]	validation_0-rmse:4.69040	validation_0-mean_absolute_error:1.44707	validation_1-rmse:3.61255	validation_1-mean_absolute_error:1.21005
# [54]	validation_0-rmse:4.64441	validation_0-mean_absolute_error:1.43660	validation_1-rmse:3.59073	validation_1-mean_absolute_error:1.20206
# [55]	validation_0-rmse:4.59781	validation_0-mean_absolute_error:1.42550	validation_1-rmse:3.56063	validation_1-mean_absolute_error:1.19274
# [56]	validation_0-rmse:4.54858	validation_0-mean_absolute_error:1.41473	validation_1-rmse:3.53877	validation_1-mean_absolute_error:1.18660
# [57]	validation_0-rmse:4.50201	validation_0-mean_absolute_error:1.40414	validation_1-rmse:3.52517	validation_1-mean_absolute_error:1.18116
# [58]	validation_0-rmse:4.45714	validation_0-mean_absolute_error:1.39239	validation_1-rmse:3.49226	validation_1-mean_absolute_error:1.17121
# [59]	validation_0-rmse:4.41160	validation_0-mean_absolute_error:1.38314	validation_1-rmse:3.47534	validation_1-mean_absolute_error:1.16531
# [60]	validation_0-rmse:4.36645	validation_0-mean_absolute_error:1.37251	validation_1-rmse:3.44835	validation_1-mean_absolute_error:1.15667
# [61]	validation_0-rmse:4.31705	validation_0-mean_absolute_error:1.36064	validation_1-rmse:3.42148	validation_1-mean_absolute_error:1.14750
# [62]	validation_0-rmse:4.27634	validation_0-mean_absolute_error:1.35118	validation_1-rmse:3.40141	validation_1-mean_absolute_error:1.14031
# [63]	validation_0-rmse:4.23620	validation_0-mean_absolute_error:1.34158	validation_1-rmse:3.37396	validation_1-mean_absolute_error:1.13249
# [64]	validation_0-rmse:4.20186	validation_0-mean_absolute_error:1.33335	validation_1-rmse:3.35565	validation_1-mean_absolute_error:1.12606
# [65]	validation_0-rmse:4.16079	validation_0-mean_absolute_error:1.32299	validation_1-rmse:3.33598	validation_1-mean_absolute_error:1.11874
# [66]	validation_0-rmse:4.12208	validation_0-mean_absolute_error:1.31455	validation_1-rmse:3.32338	validation_1-mean_absolute_error:1.11263
# [67]	validation_0-rmse:4.08323	validation_0-mean_absolute_error:1.30503	validation_1-rmse:3.30397	validation_1-mean_absolute_error:1.10480
# [68]	validation_0-rmse:4.04549	validation_0-mean_absolute_error:1.29617	validation_1-rmse:3.29427	validation_1-mean_absolute_error:1.09977
# [69]	validation_0-rmse:4.00589	validation_0-mean_absolute_error:1.28694	validation_1-rmse:3.26570	validation_1-mean_absolute_error:1.09135
# [70]	validation_0-rmse:3.96942	validation_0-mean_absolute_error:1.27718	validation_1-rmse:3.24559	validation_1-mean_absolute_error:1.08451
# [71]	validation_0-rmse:3.93477	validation_0-mean_absolute_error:1.26842	validation_1-rmse:3.21959	validation_1-mean_absolute_error:1.07684
# [72]	validation_0-rmse:3.89951	validation_0-mean_absolute_error:1.25970	validation_1-rmse:3.20394	validation_1-mean_absolute_error:1.07141
# [73]	validation_0-rmse:3.86566	validation_0-mean_absolute_error:1.25230	validation_1-rmse:3.19040	validation_1-mean_absolute_error:1.06691
# [74]	validation_0-rmse:3.83493	validation_0-mean_absolute_error:1.24355	validation_1-rmse:3.16694	validation_1-mean_absolute_error:1.05950
# [75]	validation_0-rmse:3.79892	validation_0-mean_absolute_error:1.23489	validation_1-rmse:3.15069	validation_1-mean_absolute_error:1.05254
# [76]	validation_0-rmse:3.77022	validation_0-mean_absolute_error:1.22663	validation_1-rmse:3.12804	validation_1-mean_absolute_error:1.04399
# [77]	validation_0-rmse:3.74062	validation_0-mean_absolute_error:1.21964	validation_1-rmse:3.10936	validation_1-mean_absolute_error:1.03775
# [78]	validation_0-rmse:3.71071	validation_0-mean_absolute_error:1.21225	validation_1-rmse:3.09467	validation_1-mean_absolute_error:1.03269
# [79]	validation_0-rmse:3.68232	validation_0-mean_absolute_error:1.20558	validation_1-rmse:3.07575	validation_1-mean_absolute_error:1.02619
# [80]	validation_0-rmse:3.65284	validation_0-mean_absolute_error:1.19852	validation_1-rmse:3.05665	validation_1-mean_absolute_error:1.02045
# [81]	validation_0-rmse:3.62740	validation_0-mean_absolute_error:1.19242	validation_1-rmse:3.02770	validation_1-mean_absolute_error:1.01345
# [82]	validation_0-rmse:3.60200	validation_0-mean_absolute_error:1.18651	validation_1-rmse:3.01675	validation_1-mean_absolute_error:1.01009
# [83]	validation_0-rmse:3.57273	validation_0-mean_absolute_error:1.17925	validation_1-rmse:3.00202	validation_1-mean_absolute_error:1.00441
# [84]	validation_0-rmse:3.54590	validation_0-mean_absolute_error:1.17227	validation_1-rmse:2.98911	validation_1-mean_absolute_error:0.99914
# [85]	validation_0-rmse:3.51906	validation_0-mean_absolute_error:1.16614	validation_1-rmse:2.96783	validation_1-mean_absolute_error:0.99388
# [86]	validation_0-rmse:3.49105	validation_0-mean_absolute_error:1.15897	validation_1-rmse:2.95927	validation_1-mean_absolute_error:0.98946
# [87]	validation_0-rmse:3.46340	validation_0-mean_absolute_error:1.15327	validation_1-rmse:2.94397	validation_1-mean_absolute_error:0.98620
# [88]	validation_0-rmse:3.43805	validation_0-mean_absolute_error:1.14690	validation_1-rmse:2.92358	validation_1-mean_absolute_error:0.97993
# [89]	validation_0-rmse:3.41351	validation_0-mean_absolute_error:1.14129	validation_1-rmse:2.91481	validation_1-mean_absolute_error:0.97768
# [90]	validation_0-rmse:3.38863	validation_0-mean_absolute_error:1.13581	validation_1-rmse:2.90005	validation_1-mean_absolute_error:0.97300
# [91]	validation_0-rmse:3.36571	validation_0-mean_absolute_error:1.12990	validation_1-rmse:2.88848	validation_1-mean_absolute_error:0.96994
# [92]	validation_0-rmse:3.34510	validation_0-mean_absolute_error:1.12545	validation_1-rmse:2.88361	validation_1-mean_absolute_error:0.96687
# [93]	validation_0-rmse:3.32227	validation_0-mean_absolute_error:1.11927	validation_1-rmse:2.86602	validation_1-mean_absolute_error:0.96293
# [94]	validation_0-rmse:3.29908	validation_0-mean_absolute_error:1.11315	validation_1-rmse:2.85308	validation_1-mean_absolute_error:0.95863
# [95]	validation_0-rmse:3.27734	validation_0-mean_absolute_error:1.10799	validation_1-rmse:2.83993	validation_1-mean_absolute_error:0.95458
# [96]	validation_0-rmse:3.25559	validation_0-mean_absolute_error:1.10250	validation_1-rmse:2.82555	validation_1-mean_absolute_error:0.94974
# [97]	validation_0-rmse:3.23512	validation_0-mean_absolute_error:1.09708	validation_1-rmse:2.81971	validation_1-mean_absolute_error:0.94602
# [98]	validation_0-rmse:3.21185	validation_0-mean_absolute_error:1.09215	validation_1-rmse:2.81177	validation_1-mean_absolute_error:0.94326
# [99]	validation_0-rmse:3.19100	validation_0-mean_absolute_error:1.08695	validation_1-rmse:2.80277	validation_1-mean_absolute_error:0.94006
# [100]	validation_0-rmse:3.16862	validation_0-mean_absolute_error:1.08142	validation_1-rmse:2.79227	validation_1-mean_absolute_error:0.93658
# [101]	validation_0-rmse:3.15138	validation_0-mean_absolute_error:1.07677	validation_1-rmse:2.78883	validation_1-mean_absolute_error:0.93371
# [102]	validation_0-rmse:3.12878	validation_0-mean_absolute_error:1.07118	validation_1-rmse:2.77582	validation_1-mean_absolute_error:0.92916
# [103]	validation_0-rmse:3.11087	validation_0-mean_absolute_error:1.06642	validation_1-rmse:2.76774	validation_1-mean_absolute_error:0.92656
# [104]	validation_0-rmse:3.09280	validation_0-mean_absolute_error:1.06179	validation_1-rmse:2.75693	validation_1-mean_absolute_error:0.92238
# [105]	validation_0-rmse:3.07391	validation_0-mean_absolute_error:1.05723	validation_1-rmse:2.74747	validation_1-mean_absolute_error:0.92011
# [106]	validation_0-rmse:3.05774	validation_0-mean_absolute_error:1.05278	validation_1-rmse:2.73973	validation_1-mean_absolute_error:0.91777
# [107]	validation_0-rmse:3.03995	validation_0-mean_absolute_error:1.04798	validation_1-rmse:2.73164	validation_1-mean_absolute_error:0.91344
# [108]	validation_0-rmse:3.02441	validation_0-mean_absolute_error:1.04407	validation_1-rmse:2.72021	validation_1-mean_absolute_error:0.91038
# [109]	validation_0-rmse:3.00475	validation_0-mean_absolute_error:1.03872	validation_1-rmse:2.70723	validation_1-mean_absolute_error:0.90651
# [110]	validation_0-rmse:2.98717	validation_0-mean_absolute_error:1.03424	validation_1-rmse:2.69637	validation_1-mean_absolute_error:0.90249
# [111]	validation_0-rmse:2.97157	validation_0-mean_absolute_error:1.02990	validation_1-rmse:2.68576	validation_1-mean_absolute_error:0.89939
# [112]	validation_0-rmse:2.95656	validation_0-mean_absolute_error:1.02597	validation_1-rmse:2.67440	validation_1-mean_absolute_error:0.89643
# [113]	validation_0-rmse:2.94169	validation_0-mean_absolute_error:1.02151	validation_1-rmse:2.67078	validation_1-mean_absolute_error:0.89467
# [114]	validation_0-rmse:2.92738	validation_0-mean_absolute_error:1.01855	validation_1-rmse:2.66354	validation_1-mean_absolute_error:0.89182
# [115]	validation_0-rmse:2.91186	validation_0-mean_absolute_error:1.01409	validation_1-rmse:2.65685	validation_1-mean_absolute_error:0.88954
# [116]	validation_0-rmse:2.89560	validation_0-mean_absolute_error:1.01007	validation_1-rmse:2.65229	validation_1-mean_absolute_error:0.88727
# [117]	validation_0-rmse:2.88078	validation_0-mean_absolute_error:1.00626	validation_1-rmse:2.64799	validation_1-mean_absolute_error:0.88428
# [118]	validation_0-rmse:2.86282	validation_0-mean_absolute_error:1.00126	validation_1-rmse:2.63617	validation_1-mean_absolute_error:0.87933
# [119]	validation_0-rmse:2.84774	validation_0-mean_absolute_error:0.99729	validation_1-rmse:2.62901	validation_1-mean_absolute_error:0.87719
# [120]	validation_0-rmse:2.83095	validation_0-mean_absolute_error:0.99206	validation_1-rmse:2.61100	validation_1-mean_absolute_error:0.87207
# [121]	validation_0-rmse:2.81690	validation_0-mean_absolute_error:0.98858	validation_1-rmse:2.59676	validation_1-mean_absolute_error:0.86945
# [122]	validation_0-rmse:2.80312	validation_0-mean_absolute_error:0.98504	validation_1-rmse:2.59068	validation_1-mean_absolute_error:0.86798
# [123]	validation_0-rmse:2.78956	validation_0-mean_absolute_error:0.98133	validation_1-rmse:2.58555	validation_1-mean_absolute_error:0.86517
# [124]	validation_0-rmse:2.77519	validation_0-mean_absolute_error:0.97764	validation_1-rmse:2.57595	validation_1-mean_absolute_error:0.86206
# [125]	validation_0-rmse:2.76274	validation_0-mean_absolute_error:0.97379	validation_1-rmse:2.57060	validation_1-mean_absolute_error:0.86021
# [126]	validation_0-rmse:2.74712	validation_0-mean_absolute_error:0.96934	validation_1-rmse:2.55786	validation_1-mean_absolute_error:0.85697
# [127]	validation_0-rmse:2.73240	validation_0-mean_absolute_error:0.96553	validation_1-rmse:2.54981	validation_1-mean_absolute_error:0.85407
# [128]	validation_0-rmse:2.71759	validation_0-mean_absolute_error:0.96088	validation_1-rmse:2.54039	validation_1-mean_absolute_error:0.85164
# [129]	validation_0-rmse:2.70343	validation_0-mean_absolute_error:0.95699	validation_1-rmse:2.53497	validation_1-mean_absolute_error:0.85023
# [130]	validation_0-rmse:2.69170	validation_0-mean_absolute_error:0.95379	validation_1-rmse:2.52683	validation_1-mean_absolute_error:0.84782
# [131]	validation_0-rmse:2.67910	validation_0-mean_absolute_error:0.95017	validation_1-rmse:2.52034	validation_1-mean_absolute_error:0.84641
# [132]	validation_0-rmse:2.66895	validation_0-mean_absolute_error:0.94750	validation_1-rmse:2.51893	validation_1-mean_absolute_error:0.84593
# [133]	validation_0-rmse:2.65775	validation_0-mean_absolute_error:0.94435	validation_1-rmse:2.51432	validation_1-mean_absolute_error:0.84418
# [134]	validation_0-rmse:2.64545	validation_0-mean_absolute_error:0.94080	validation_1-rmse:2.50929	validation_1-mean_absolute_error:0.84199
# [135]	validation_0-rmse:2.63466	validation_0-mean_absolute_error:0.93828	validation_1-rmse:2.50726	validation_1-mean_absolute_error:0.84099
# [136]	validation_0-rmse:2.62382	validation_0-mean_absolute_error:0.93522	validation_1-rmse:2.49687	validation_1-mean_absolute_error:0.83876
# [137]	validation_0-rmse:2.61311	validation_0-mean_absolute_error:0.93244	validation_1-rmse:2.49268	validation_1-mean_absolute_error:0.83721
# [138]	validation_0-rmse:2.60242	validation_0-mean_absolute_error:0.92923	validation_1-rmse:2.48383	validation_1-mean_absolute_error:0.83556
# [139]	validation_0-rmse:2.59196	validation_0-mean_absolute_error:0.92645	validation_1-rmse:2.47410	validation_1-mean_absolute_error:0.83323
# [140]	validation_0-rmse:2.57907	validation_0-mean_absolute_error:0.92268	validation_1-rmse:2.45672	validation_1-mean_absolute_error:0.82910
# [141]	validation_0-rmse:2.56798	validation_0-mean_absolute_error:0.91941	validation_1-rmse:2.44976	validation_1-mean_absolute_error:0.82671
# [142]	validation_0-rmse:2.55772	validation_0-mean_absolute_error:0.91617	validation_1-rmse:2.44663	validation_1-mean_absolute_error:0.82442
# [143]	validation_0-rmse:2.54770	validation_0-mean_absolute_error:0.91304	validation_1-rmse:2.43347	validation_1-mean_absolute_error:0.82126
# [144]	validation_0-rmse:2.53638	validation_0-mean_absolute_error:0.90949	validation_1-rmse:2.42830	validation_1-mean_absolute_error:0.81846
# [145]	validation_0-rmse:2.52223	validation_0-mean_absolute_error:0.90575	validation_1-rmse:2.41587	validation_1-mean_absolute_error:0.81624
# [146]	validation_0-rmse:2.51228	validation_0-mean_absolute_error:0.90284	validation_1-rmse:2.40866	validation_1-mean_absolute_error:0.81337
# [147]	validation_0-rmse:2.50009	validation_0-mean_absolute_error:0.89911	validation_1-rmse:2.39891	validation_1-mean_absolute_error:0.81202
# [148]	validation_0-rmse:2.48973	validation_0-mean_absolute_error:0.89631	validation_1-rmse:2.39396	validation_1-mean_absolute_error:0.80954
# [149]	validation_0-rmse:2.47926	validation_0-mean_absolute_error:0.89277	validation_1-rmse:2.37571	validation_1-mean_absolute_error:0.80534
# [150]	validation_0-rmse:2.46775	validation_0-mean_absolute_error:0.88907	validation_1-rmse:2.36582	validation_1-mean_absolute_error:0.80316
# [151]	validation_0-rmse:2.45702	validation_0-mean_absolute_error:0.88602	validation_1-rmse:2.35535	validation_1-mean_absolute_error:0.80071
# [152]	validation_0-rmse:2.44930	validation_0-mean_absolute_error:0.88390	validation_1-rmse:2.35391	validation_1-mean_absolute_error:0.79995
# [153]	validation_0-rmse:2.44285	validation_0-mean_absolute_error:0.88245	validation_1-rmse:2.35174	validation_1-mean_absolute_error:0.79835
# [154]	validation_0-rmse:2.43100	validation_0-mean_absolute_error:0.87849	validation_1-rmse:2.33964	validation_1-mean_absolute_error:0.79554
# [155]	validation_0-rmse:2.42360	validation_0-mean_absolute_error:0.87633	validation_1-rmse:2.33206	validation_1-mean_absolute_error:0.79354
# [156]	validation_0-rmse:2.41533	validation_0-mean_absolute_error:0.87382	validation_1-rmse:2.33041	validation_1-mean_absolute_error:0.79246
# [157]	validation_0-rmse:2.40579	validation_0-mean_absolute_error:0.87070	validation_1-rmse:2.32398	validation_1-mean_absolute_error:0.79118
# [158]	validation_0-rmse:2.39485	validation_0-mean_absolute_error:0.86763	validation_1-rmse:2.30676	validation_1-mean_absolute_error:0.78735
# [159]	validation_0-rmse:2.38714	validation_0-mean_absolute_error:0.86535	validation_1-rmse:2.30189	validation_1-mean_absolute_error:0.78572
# [160]	validation_0-rmse:2.37581	validation_0-mean_absolute_error:0.86208	validation_1-rmse:2.29641	validation_1-mean_absolute_error:0.78350
# [161]	validation_0-rmse:2.36592	validation_0-mean_absolute_error:0.85902	validation_1-rmse:2.28269	validation_1-mean_absolute_error:0.78034
# [162]	validation_0-rmse:2.35608	validation_0-mean_absolute_error:0.85589	validation_1-rmse:2.26789	validation_1-mean_absolute_error:0.77731
# [163]	validation_0-rmse:2.34818	validation_0-mean_absolute_error:0.85317	validation_1-rmse:2.26090	validation_1-mean_absolute_error:0.77545
# [164]	validation_0-rmse:2.33888	validation_0-mean_absolute_error:0.85015	validation_1-rmse:2.24877	validation_1-mean_absolute_error:0.77218
# [165]	validation_0-rmse:2.33094	validation_0-mean_absolute_error:0.84785	validation_1-rmse:2.24506	validation_1-mean_absolute_error:0.77199
# [166]	validation_0-rmse:2.32032	validation_0-mean_absolute_error:0.84468	validation_1-rmse:2.23413	validation_1-mean_absolute_error:0.76897
# [167]	validation_0-rmse:2.31269	validation_0-mean_absolute_error:0.84209	validation_1-rmse:2.23101	validation_1-mean_absolute_error:0.76743
# [168]	validation_0-rmse:2.30367	validation_0-mean_absolute_error:0.83942	validation_1-rmse:2.22109	validation_1-mean_absolute_error:0.76498
# [169]	validation_0-rmse:2.29793	validation_0-mean_absolute_error:0.83770	validation_1-rmse:2.21913	validation_1-mean_absolute_error:0.76373
# [170]	validation_0-rmse:2.28908	validation_0-mean_absolute_error:0.83438	validation_1-rmse:2.20772	validation_1-mean_absolute_error:0.76074
# [171]	validation_0-rmse:2.28436	validation_0-mean_absolute_error:0.83259	validation_1-rmse:2.20366	validation_1-mean_absolute_error:0.75926
# [172]	validation_0-rmse:2.27620	validation_0-mean_absolute_error:0.82984	validation_1-rmse:2.19675	validation_1-mean_absolute_error:0.75615
# [173]	validation_0-rmse:2.27059	validation_0-mean_absolute_error:0.82777	validation_1-rmse:2.19445	validation_1-mean_absolute_error:0.75445
# [174]	validation_0-rmse:2.26207	validation_0-mean_absolute_error:0.82529	validation_1-rmse:2.19182	validation_1-mean_absolute_error:0.75210
# [175]	validation_0-rmse:2.25839	validation_0-mean_absolute_error:0.82452	validation_1-rmse:2.19025	validation_1-mean_absolute_error:0.75143
# [176]	validation_0-rmse:2.25132	validation_0-mean_absolute_error:0.82193	validation_1-rmse:2.17996	validation_1-mean_absolute_error:0.74880
# [177]	validation_0-rmse:2.24422	validation_0-mean_absolute_error:0.81944	validation_1-rmse:2.17586	validation_1-mean_absolute_error:0.74723
# [178]	validation_0-rmse:2.23729	validation_0-mean_absolute_error:0.81697	validation_1-rmse:2.17015	validation_1-mean_absolute_error:0.74545
# [179]	validation_0-rmse:2.23104	validation_0-mean_absolute_error:0.81468	validation_1-rmse:2.17034	validation_1-mean_absolute_error:0.74500
# [180]	validation_0-rmse:2.22550	validation_0-mean_absolute_error:0.81298	validation_1-rmse:2.15964	validation_1-mean_absolute_error:0.74348
# [181]	validation_0-rmse:2.21909	validation_0-mean_absolute_error:0.81103	validation_1-rmse:2.15599	validation_1-mean_absolute_error:0.74198
# [182]	validation_0-rmse:2.21255	validation_0-mean_absolute_error:0.80914	validation_1-rmse:2.15407	validation_1-mean_absolute_error:0.74095
# [183]	validation_0-rmse:2.20317	validation_0-mean_absolute_error:0.80594	validation_1-rmse:2.14646	validation_1-mean_absolute_error:0.73951
# [184]	validation_0-rmse:2.19542	validation_0-mean_absolute_error:0.80344	validation_1-rmse:2.13721	validation_1-mean_absolute_error:0.73741
# [185]	validation_0-rmse:2.18887	validation_0-mean_absolute_error:0.80163	validation_1-rmse:2.13141	validation_1-mean_absolute_error:0.73594
# [186]	validation_0-rmse:2.17933	validation_0-mean_absolute_error:0.79892	validation_1-rmse:2.12263	validation_1-mean_absolute_error:0.73365
# [187]	validation_0-rmse:2.17098	validation_0-mean_absolute_error:0.79630	validation_1-rmse:2.11330	validation_1-mean_absolute_error:0.73177
# [188]	validation_0-rmse:2.16474	validation_0-mean_absolute_error:0.79395	validation_1-rmse:2.11089	validation_1-mean_absolute_error:0.72994
# [189]	validation_0-rmse:2.16034	validation_0-mean_absolute_error:0.79268	validation_1-rmse:2.10938	validation_1-mean_absolute_error:0.72882
# [190]	validation_0-rmse:2.15334	validation_0-mean_absolute_error:0.79058	validation_1-rmse:2.10317	validation_1-mean_absolute_error:0.72765
# [191]	validation_0-rmse:2.14672	validation_0-mean_absolute_error:0.78856	validation_1-rmse:2.09401	validation_1-mean_absolute_error:0.72599
# [192]	validation_0-rmse:2.14082	validation_0-mean_absolute_error:0.78624	validation_1-rmse:2.09102	validation_1-mean_absolute_error:0.72482
# [193]	validation_0-rmse:2.13442	validation_0-mean_absolute_error:0.78407	validation_1-rmse:2.08955	validation_1-mean_absolute_error:0.72354
# [194]	validation_0-rmse:2.12890	validation_0-mean_absolute_error:0.78219	validation_1-rmse:2.08180	validation_1-mean_absolute_error:0.72173
# [195]	validation_0-rmse:2.12443	validation_0-mean_absolute_error:0.78074	validation_1-rmse:2.07326	validation_1-mean_absolute_error:0.71980
# [196]	validation_0-rmse:2.11668	validation_0-mean_absolute_error:0.77828	validation_1-rmse:2.06673	validation_1-mean_absolute_error:0.71787
# [197]	validation_0-rmse:2.10997	validation_0-mean_absolute_error:0.77559	validation_1-rmse:2.05610	validation_1-mean_absolute_error:0.71412
# [198]	validation_0-rmse:2.10544	validation_0-mean_absolute_error:0.77423	validation_1-rmse:2.04919	validation_1-mean_absolute_error:0.71272
# [199]	validation_0-rmse:2.09984	validation_0-mean_absolute_error:0.77240	validation_1-rmse:2.04225	validation_1-mean_absolute_error:0.71060
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              device=None, early_stopping_rounds=10, enable_categorical=False,
#              eta=0.05,
#              eval_metric=<function mean_absolute_error at 0x000001D96B38A8B0>,
#              feature_types=None, gamma=1, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.025, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=1, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, ...)

# %%
df_prediction=combined_input_data_.copy()
X_all = df_prediction[selected_features_xgb_regr]
y_pred = reg.predict(X_all)
df_prediction['DMG_predicted']=y_pred

# %%
df_prediction
# Out:
#           Mun_Code     typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 0      PH015501000  durian2006           24.175000             2.408333
# 1      PH015502000  durian2006           14.930000             1.650000
# 2      PH015503000  durian2006           14.933333             1.193056
# 3      PH015504000  durian2006           30.475000             4.429167
# 4      PH015506000  durian2006           41.950000             4.139583
# ...            ...         ...                 ...                  ...
# 38585  PH175318000     rai2021                 NaN                  NaN
# 38586  PH175319000     rai2021                 NaN                  NaN
# 38587  PH175320000     rai2021                 NaN                  NaN
# 38588  PH175322000     rai2021                 NaN                  NaN
# 38590  PH175324000     rai2021                 NaN                  NaN
#
#        HAZ_rainfall_max_24h  HAZ_v_max  HAZ_dis_track_min  GEN_landslide_per  \
# 0                  0.957639  10.946196         274.953818               1.52
# 1                  0.586250  12.109652         252.828578               0.00
# 2                  0.590278  10.545990         283.812673               1.45
# 3                  1.211458  11.875702         258.590255               0.00
# 4                  1.541146  10.711236         280.619001               0.00
# ...                     ...        ...                ...                ...
# 38585                   NaN  52.610862           2.527036               1.86
# 38586                   NaN  52.360964           8.712423               3.69
# 38587                   NaN  51.415787          41.301466               3.40
# 38588                   NaN  20.013717         179.811593               0.84
# 38590                   NaN  22.217084         133.019792               2.43
#
#        GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  VUL_LightRoof_StrongWall  \
# 0                    1.28            1.28  ...                  0.667374
# 1                    0.00            0.00  ...                  0.675125
# 2                    2.49            2.49  ...                  0.798692
# 3                    0.00            0.00  ...                  0.228696
# 4                    0.00            0.00  ...                  0.443968
# ...                   ...             ...  ...                       ...
# 38585               10.56           10.50  ...                  1.729652
# 38586               17.35           17.30  ...                  1.461160
# 38587                1.14            1.14  ...                  1.137998
# 38588                0.11            0.11  ...                  0.301724
# 38590                2.94            2.94  ...                  0.808028
#
#        VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 0                    15.592295                   0.075838
# 1                     7.100454                   0.023280
# 2                     7.020084                   0.084073
# 3                     4.434722                   0.059660
# 4                     3.842621                   0.015309
# ...                        ...                        ...
# 38585                53.292866                   0.117486
# 38586                44.699568                   0.387655
# 38587                50.228225                   0.043769
# 38588                41.206897                   0.086207
# 38590                58.569008                   0.052131
#
#        VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 0                         0.000000                    0.015168
# 1                         0.011640                    0.000000
# 2                         0.051378                    0.065390
# 3                         0.000000                    0.079547
# 4                         0.000000                    0.015309
# ...                            ...                         ...
# 38585                     0.006527                    0.045689
# 38586                     0.000000                    0.014910
# 38587                     0.000000                    0.025011
# 38588                     0.021552                    0.107759
# 38590                     0.026065                    0.000000
#
#        VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 0                          0.075838               2.131755
# 1                          0.128041               1.589369
# 2                          0.186829               1.335444
# 3                          0.049717               1.651998
# 4                          0.061237               1.126319
# ...                             ...                    ...
# 38585                      0.026108               2.475596
# 38586                      0.014910               2.343750
# 38587                      0.043769               2.795184
# 38588                      0.193966               2.303987
# 38590                      0.000000               2.287383
#
#        VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg  DMG_predicted
# 0                             39.148724      0.000000       0.016522
# 1                             38.892507      0.000000       0.028305
# 2                             21.406118      0.000000      -0.006110
# 3                             19.054421      0.000000       0.219535
# 4                             13.367623      0.000000       0.157344
# ...                                 ...           ...            ...
# 38585                         43.202056     24.991841      19.424965
# 38586                         45.603868     22.677799      14.921251
# 38587                         55.569747     10.260739       7.396484
# 38588                         38.879785      0.000000       0.216123
# 38590                         53.972503      0.026065       0.308581
#
# [9112 rows x 39 columns]

# %%
dref_probabilities = {
            "100k": [100000, 0.5],
            "80k": [80000, 0.6],
            "70k": [70000, 0.7],
            "50k": [50000, 0.8],
            "30k": [30000, 0.9],
        }


dref_probabilities_10 = {
            "33": [33,'Moderate'],
            "50": [50,'High'],
            "70":[70,'Very High'],
        }


cerf_probabilities = {
    "80k": [80000, 0.5],
    "50k": [50000, 0.6],
    "30k": [30000, 0.7],
    "10k": [10000, 0.8],
    "5k": [5000, 0.95],
}
        
        
START_probabilities = {
    'PH166700000':{
        "8k": [8000, 0.8],
        "10k": [10000, 0.8],
        "15k": [15000, 0.7],
        "20k": [20000, 0.5],
        "25k": [25000, 0.5],    
         
        },
    'PH021500000':{
        "16k": [16000, 0.8],
        "18k": [18000, 0.8],
        "20k": [20000, 0.7],
        "25k": [25000, 0.5],
        "28.5k": [28500, 0.5], 
   
        },
    'PH082600000':{
        "18k": [18000, 0.8],
        "20k": [20000, 0.8],
        "25k": [25000, 0.7],
        "30k": [30000, 0.6],
        "40k": [40000, 0.5],
        },
}

# Only select regions 5 and 8
cerf_regions = ["PH05", "PH08"]

start_regions = {'PH166700000':'surigaodelnorte', 'PH021500000':'cagayan', 'PH082600000':'EasternSamar'}

cerf_trigger_list={}
start_trigger_dic={}
DREF_trigger_list={}
DREF_trigger_list_10={}


file_name = ("IBF-typhoon-model\\data\\wind_data\\output\\")#historical_events_windgrid_output.csv")
#historical_events_windgrid_output_hrs
wind_path = os.path.join(wor_dir, file_name)
#wind_path = os.path.join(wor_dir,"data/wind_data/output_storm2")
#os.chdir(wind_path)

dfs=[]
def Number_affected(x):
    return np.exp(6.80943612231606) * x ** 0.46982114400549513
    
def division(x, y):
    try:
        value = int((x * y)/100)
        
    except:
        value = np.nan
    
    return x if value>x else value 

filename_list_wind = sorted(list(Path(os.path.join(wor_dir ,"IBF-typhoon-model/data/wind_data/hindcast")).glob('*.csv')))
inx_=0
index2=0
inx_3=0
 
for file_wind in filename_list_wind:
    #windfiles = glob.glob(f'*_{index}.csv')
    index=os.path.basename(file_wind)
    index_=index.split('.')[0]
    event_name=index.split('_')[1]
    lead_time2=index.split('_')[-1].split('.')[0]
    #f_path = os.path.join(wind_path,f'{index}.csv')
 
    
    df_temp = pd.read_csv(file_wind)
    
    #if len(df_temp.index)>1:
    df_temp.rename(columns={'adm3_pcode':'Mun_Code','name':'typhoon'},inplace=True)
        
    df_wind=df_temp[['storm_id','Mun_Code','v_max','typhoon','forecast_time','dis_track_min']]#.groupby("Mun_Code").agg({'v_max':'max'})
     
 
    df_wind_final = df_wind#pd.concat(dfs,axis=0, join='outer')    
    df_total=pd.merge(df_wind_final, df_predisasters,  how='left', left_on='Mun_Code', right_on = 'Mun_Code')
    df_total=df_total[df_total['v_max'].notnull()]
    df_total.rename(columns ={           'v_max':'HAZ_v_max',
                                        'dis_track_min':'HAZ_dis_track_min',
                                        'landslide_per':'GEN_landslide_per',
                                        'stormsurge_per':'GEN_stormsurge_per',
                                        'Bu_p_inSSA':'GEN_Bu_p_inSSA',
                                        'Bu_p_LS':'GEN_Bu_p_LS',
                                         'Red_per_LSbldg':'GEN_Red_per_LSbldg',
                                        'Or_per_LSblg':'GEN_Or_per_LSblg',
                                         'Yel_per_LSSAb':'GEN_Yel_per_LSSAb',
                                        'RED_per_SSAbldg':'GEN_RED_per_SSAbldg',
                                         'OR_per_SSAbldg':'GEN_OR_per_SSAbldg',
                                        'Yellow_per_LSbl':'GEN_Yellow_per_LSbl',
                                         'mean_slope':'TOP_mean_slope',
                                        'mean_elevation_m':'TOP_mean_elevation_m',
                                         'ruggedness_stdev':'TOP_ruggedness_stdev',
                                        'mean_ruggedness':'TOP_mean_ruggedness',
                                         'slope_stdev':'TOP_slope_stdev',
                                         'poverty_perc':'VUL_poverty_perc',
                                        'with_coast':'GEN_with_coast',
                                         'coast_length':'GEN_coast_length',
                                         'Housing Units':'VUL_Housing_Units',
                                        'Strong Roof/Strong Wall':"VUL_StrongRoof_StrongWall",
                                        'Strong Roof/Light Wall':'VUL_StrongRoof_LightWall',
                                        'Strong Roof/Salvage Wall':'VUL_StrongRoof_SalvageWall',
                                        'Light Roof/Strong Wall':'VUL_LightRoof_StrongWall',
                                        'Light Roof/Light Wall':'VUL_LightRoof_LightWall',
                                        'Light Roof/Salvage Wall':'VUL_LightRoof_SalvageWall',
                                        'Salvaged Roof/Strong Wall':'VUL_SalvagedRoof_StrongWall',
                                        'Salvaged Roof/Light Wall':'VUL_SalvagedRoof_LightWall',
                                        'Salvaged Roof/Salvage Wall':'VUL_SalvagedRoof_SalvageWall',
                                        'vulnerable_groups':'VUL_vulnerable_groups',
                                        'pantawid_pamilya_beneficiary':'VUL_pantawid_pamilya_beneficiary'},inplace=True)
    #df_total = df_total.filter(selected_cols)
    X_all = df_total[selected_features_xgb_regr]
    y_pred = reg.predict(X_all)
    df_total['DMG_predicted']=y_pred 
    y_pred[y_pred<10]=0
    y_pred[y_pred>0]=1
    df_total['Trigger']=y_pred 
    IMPACT_DF1 = pd.merge(df_total, df_predisasters[['Housing Units','Mun_Code']],  how='left', left_on='Mun_Code', right_on = 'Mun_Code') 
    IMPACT_DF1["number_dmg_Build_prediction"] = IMPACT_DF1.apply(lambda x: division(x["Housing Units"], x["DMG_predicted"]), axis=1).values
  
    
    IMPACT_DF1["number_affected_pop__prediction"] = IMPACT_DF1.apply(lambda x: Number_affected(x["number_dmg_Build_prediction"]), axis=1).values
    
    impact_scenarios=['number_dmg_Build_prediction','number_affected_pop__prediction']
    
    IMPACT_DF1[impact_scenarios] = IMPACT_DF1[impact_scenarios].astype('int') 
    IMPACT_DF1['Prov_Code']=IMPACT_DF1.apply(lambda x:str(x.Mun_Code[:6])+'00000',axis=1)
    IMPACT_DF1['typhoon_year']=IMPACT_DF1.apply(lambda x:x.typhoon+str(x.storm_id[:4]),axis=1)
    
    
    
     
    impact_path = os.path.join(wor_dir,"IBF-typhoon-model/data/results/hindcast",f"{index}impact.csv")
 
    

    
    
    IMPACT_DF12=IMPACT_DF1[['Prov_Code','Mun_Code','storm_id','typhoon_year', 'forecast_time','DMG_predicted','Trigger','number_dmg_Build_prediction','number_affected_pop__prediction']]
    IMPACT_DF12.to_csv(impact_path) 
    
    dfs.append(IMPACT_DF12)
    
    
    probability_impact=IMPACT_DF12.groupby(['storm_id','typhoon_year','forecast_time']).agg(NUmber_of_affected_municipality=('Mun_Code','count'),
                                        average_ML_Model=('DMG_predicted', 'mean'),
                                        Trigger_ML_Model=('Trigger', sum),
                                        Total_affected_ML_Model=('number_affected_pop__prediction', sum),
                                        Total_buildings_ML_Model=('number_dmg_Build_prediction', sum)).sort_values(by='Total_buildings_ML_Model',ascending=False).reset_index()
    
  
    
    
    ### DREF trigger based on 10% damage per manucipality  
    trigger_status1={}
    probability_impact['Trigger']=probability_impact.apply(lambda x:1 if x.Trigger_ML_Model>2 else 0,axis=1)
    agg_impact_10 = probability_impact["Trigger"].values
    trigger_stat_dref10 = 100*(sum(agg_impact_10) /len(agg_impact_10))
    
    for key, values in dref_probabilities_10.items():
        inx_3=inx_3+1
        dref_trigger_status10 = {}
        thershold=values[1]
        if  (trigger_stat_dref10 > values[0]):
            trigger_stat_1=True
 
        else:
            trigger_stat_1=False
 
        dref_trigger_status10['lead_time'] = int(lead_time2)-10
        dref_trigger_status10['triggered_prob'] = thershold 
        dref_trigger_status10['EVENT'] = event_name 
        dref_trigger_status10['trigger_stat'] = trigger_stat_1         
        trigger_status1[inx_3] = dref_trigger_status10
        index3=event_name+'_'+lead_time2+str(inx_3)
        DREF_trigger_list_10[index3] = dref_trigger_status10
        
    
    ### DREF trigger based on probability of Houses 
    agg_impact = probability_impact["Total_buildings_ML_Model"].values
    for key, values in dref_probabilities.items():
        dref_trigger_status = {}
        index2=index2+1

        trigger_stat = 100*(sum(1.13*i > values[0] for i in agg_impact) /len(agg_impact))
        
        if  (values[1] < (sum(1.13*i > values[0] for i in agg_impact) /len(agg_impact))):
            trigger_stat_=True
            thershold=key 
        else:
            trigger_stat_=False
            thershold=key
        
        dref_trigger_status['thre_name'] = key
        dref_trigger_status['thr_value'] = int(trigger_stat)      
        dref_trigger_status['event'] = event_name 
        dref_trigger_status['lead_time'] = int(lead_time2)-10
        dref_trigger_status['trigger_stat'] = trigger_stat_
        index=event_name+'_'+lead_time2+str(index2)
        
        DREF_trigger_list[index] = dref_trigger_status
    
        
    #DREF_trigger_list[event_name] = dref_trigger_status
    
    
    
    ############ check trigger for START project
    
    start_trigger_status = {}
    
    provinces_names={'PH166700000':'SurigaoDeLnorte','PH021500000':'Cagayan','PH082600000':'EasternSamar'}
    
    for provinces in ['PH166700000','PH021500000','PH082600000']:
        triggers=START_probabilities[provinces]
        prov_name=provinces_names[provinces]
        df_trig=IMPACT_DF12.query('Prov_Code==@provinces')
        if not df_trig.empty:  
            probability_impact=df_trig.groupby(['storm_id','typhoon_year','forecast_time']).agg(
                                                Total_affected_ML_Model=('number_affected_pop__prediction', sum),
                                                Total_buildings_ML_Model=('number_dmg_Build_prediction', sum)).sort_values(by='Total_buildings_ML_Model',ascending=False).reset_index()
            
                
            ######## calculate probability for impact
            
            
            agg_impact = probability_impact["Total_affected_ML_Model"].values
     
            thershold='NAN'
            
            

            for key, values in triggers.items():
                inx_=inx_+1
                start_trigger_status1 = {}
                trigger_stat = 100*(sum(i > values[0] for i in agg_impact) /len(agg_impact)       )
                #start_trigger_status1[key] = int(trigger_stat)
                start_trigger_status1['thr_name']=key
                start_trigger_status1['thr_value']=int(trigger_stat)

                if  (values[1] < (sum(i > values[0] for i in agg_impact) /len(agg_impact))):
                    trigger_stat_=True
                    thershold=key 
                else:
                    trigger_stat_=False
                    thershold=key
            #start_trigger_list.append({'event':event_name, 'province':prov_name,                                      'lead_time':lead_time2,                                      'status':trigger_stat_,                                      'threshold':thershold})
            
                #start_trigger_status['event'] = event_name
 

                start_trigger_status1['PROVINCE'] = prov_name
                start_trigger_status1['EVENT'] = event_name
                start_trigger_status1['lead_time'] = lead_time2
                start_trigger_status1['trigger_stat'] = trigger_stat_         
                index=event_name+'_'+lead_time2+str(index2)
                start_trigger_dic[index] = start_trigger_status1
       
            #start_trigger[prov_name] =start_trigger_status
            
            #start_trigger_list.append(start_trigger_status)
    #start_trigger_list[event_name] = start_trigger_status
     

Trigger_status=True
impact_path_ = os.path.join(wor_dir,"IBF-typhoon-model/data/results/dref_trigger_table_10%.csv")
pd.DataFrame.from_dict(DREF_trigger_list_10,orient='index').query('trigger_stat==@Trigger_status').to_csv(impact_path_) 

impact_path_ = os.path.join(wor_dir,"IBF-typhoon-model/data/results/dref_trigger_table_prob.csv")
pd.DataFrame.from_dict(DREF_trigger_list,orient='index').query('trigger_stat==@Trigger_status').to_csv(impact_path_) 

impact_path_ = os.path.join(wor_dir,"IBF-typhoon-model/data/results/start_trigger_table_prob.csv")
pd.DataFrame.from_dict(start_trigger_dic,orient='index').query('trigger_stat==@Trigger_status').to_csv(impact_path_)
