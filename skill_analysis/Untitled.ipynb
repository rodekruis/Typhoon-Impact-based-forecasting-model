# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-940907b622a2> in <module>
#      21 from netCDF4 import Dataset
#      22 import itertools
# ---> 23 from functions import *
#      24
#
# ModuleNotFoundError: No module named 'functions'
